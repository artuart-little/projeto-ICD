# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import json

MEU_COOKIE = "i18nextprimary=pt; __Host-next-auth.csrf-token=e32fe809eb288de04708b98411432664e2f35d59148f210351984d8576be5418%7Cb3be9ab8c702f7efcd317baba6d4b8b8c7324c59937b4441694dd0f87bb32d90; __Secure-next-auth.callback-url=https%3A%2F%2Fskoob.com.br; AdoptConsent=; AdoptVisitorId=EwEwHGDsDGkMwFpjHggLAIwGxoQQxBADMEBOARgFM84jIs44Q8g=; theme=skoob; modeType=light; mode=light; afUserId=0df8d380-8431-488a-940c-2d506feffa1b-p; AF_SYNC=1775316166287; _ga=GA1.1.38341356.1775316166; token=eJwVi9sOgiAAQP%2FFD3ATL%2BVjqTlYwDQq5KXNSxPQstxS%2FPp05%2B3sHKsxqC3TSlKJ4HWBDpFwhK%2FcryIYQD3wW4RCe40GsQlV%2BPSeGNKvMNIVShuannrMKiD6vBPb3HdtvbarcwnDM2F6IpdJCt5OUL1nslSAqGSm7OA8MxtT7IF4HMJfuS%2BP4%2FnxyRPka483NeSzCcCOul8U13GWWX%2FZATne; tokenClient=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpZCI6IjY5OWEyNmNmNTNlYjkyOGFmMTc2ZmRlZiIsImlhdCI6MTc3NTMxNTkwNSwiZXhwIjoxNzc2NjExOTA1fQ.MOM42Dsp9vb8bBsL_qREJ5k4XedIXxy627O3rJDdDQQ; user=eJx1kEFOxDAMRa9SZT20pYhCsxoJhMQOiQNUaeIUQ5NUcToSGs1hOAsXw5kpaGbB0s%2Ff3%2F7ei4UgCrkXaIQUbdepptX29gaGrrlX9vqutQas2AivHLDiJYZ3SKF4fnhkmIfXxnY%2BdVAbbuwgokUwvSMk44W0aiLYCKU1zIl5guhIyBQXpki9%2B%2BzZwOIEv9ABkRqh12HxScj6j9AZ8iHxHq0SBn%2FO0e8wXSjn42QElXPWxfz9NaJXVExoFPHF9BHCALEn9DrneT3VhQEyUDwBJwKMgeuiqZuWJ9Z7%2ByVOrH9LaSZZVUefUgdXDrFaJdV%2Ff726eBo4hdlqhSXTvGo7Zp4txeHwA3MHlNk%3D; u_cache=1; _dd_s=aid=1125f073-e01a-4a7d-97eb-1e20874eac90&rum=2&id=136c0ffd-d7e9-4966-accc-5930e31f9ec2&created=1775316164837&expire=1775317215209; _ga_YTCGX9CEP8=GS2.1.s1775316166$o1$g1$t1775316315$j42$l0$h0"

HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36",
    "Cookie": MEU_COOKIE,
    "Content-Type": "application/json",
    "Next-Action": "4090d64f1036448c4b0fab7df360388f1baee2804a",
    "Next-Router-State-Tree": "%5B%22%22%2C%7B%22children%22%3A%5B%5B%22lng%22%2C%22pt%22%2C%22d%22%5D%2C%7B%22children%22%3A%5B%22(search)%22%2C%7B%22children%22%3A%5B%22search%22%2C%7B%22children%22%3A%5B%22__PAGE__%3F%7B%5C%22tab%5C%22%3A%5C%22book%5C%22%7D%22%2C%7B%7D%2C%22%2Fpt%2Fsearch%3Ftab%3Dbook%22%2C%22refresh%22%5D%7D%5D%7D%5D%7D%5D%7D%2Cnull%2Cnull%2Ctrue%5D",
    "Accept": "text/x-component" 
}

# %%
'''#OBTER LINKS DOS TOP 100 LIVROS

links_livros = []
print("Iniciando a busca via API...")

for pagina in range(1, 6):
    
    url_api = f"https://prd-api.skoob.com.br/api/v1/book/top-books?page={pagina}&limit=20&ranking_type=read"
    
    print(f"Buscando página {pagina}...")
    resposta = requests.get(url_api, headers=HEADERS)
    
    if resposta.status_code == 200:
        dados_json = resposta.json()
        
        lista_de_livros = dados_json.get('items', []) 
        
        for livro in lista_de_livros:
            id_livro = livro.get('edition_id') 
            
            if id_livro:
                link_completo = f"https://www.skoob.com.br/pt/book/{id_livro}"
                
                if link_completo not in links_livros:
                    links_livros.append(link_completo)
                    
        time.sleep(random.uniform(1.5, 3.0)) # Pausa educada
        
    else:
        print(f"Erro na página {pagina}. Status: {resposta.status_code}")

print(f"\nSucesso! {len(links_livros)} links gerados.")'''
# Out:
#   Cell In[2], line 32
#     print(f"\nSucesso! {len(links_livros)} links gerados.")'''
#                                                            ^
# _IncompleteInputError: incomplete input

# %%
#OBTER LINK DE TODOS OS LIVROS

url_api = "https://www.skoob.com.br/pt/search?tab=book"

# Teste nas 3 primeiras páginas. Altere TOTAL_PAGINAS para obter tudo.
TOTAL_PAGINAS = 3
ARQUIVO_LINKS = "links_todos_livros.txt"

with open(ARQUIVO_LINKS, 'a', encoding='utf-8') as f:
    for pagina in range(1, TOTAL_PAGINAS+1): 
        
        payload = [{"params": {"page": pagina, "limit": 12, "searchType": "book"}}]
        
        try:
            resposta = requests.post(url_api, headers=HEADERS, json=payload, timeout=15)
            
            if resposta.status_code == 200:
                texto_bruto = resposta.text
                livros_encontrados = False
                
                for linha in texto_bruto.split('\n'):
                    if '"total_items"' in linha and '"items"' in linha:
                        inicio_json = linha.find('{')
                        if inicio_json != -1:
                            json_limpo = linha[inicio_json:]
                            dados = json.loads(json_limpo)
                            
                            lista_de_livros = dados.get('items', [])
                            for livro in lista_de_livros:
                                id_livro = livro.get('edition_id')
                                
                                if id_livro:
                                    link_completo = f"https://www.skoob.com.br/pt/book/{id_livro}\n"
                                    f.write(link_completo)
                                    
                            print(f"Sucesso! Página {pagina} processada. {len(lista_de_livros)} links extraídos.")
                            livros_encontrados = True
                            break
                
                if not livros_encontrados:
                    print(f"Página {pagina}: Conexão OK, mas não achou os dados. O servidor pode ter retornado HTML de novo.")
                    
            else:
                print(f"Erro na página {pagina}. Status: {resposta.status_code}")
                
        except Exception as e:
            print(f"Erro de conexão na requisição: {e}")
            
        time.sleep(random.uniform(1.5, 3.0))

print(f"\nTeste finalizado! Verifique o arquivo '{ARQUIVO_LINKS}' no seu diretório.")
# Out:
# Sucesso! Página 1 processada. 12 links extraídos.
# Sucesso! Página 2 processada. 12 links extraídos.
# Sucesso! Página 3 processada. 12 links extraídos.
#
# Teste finalizado! Verifique o arquivo 'links_todos_livros.txt' no seu diretório.

# %%
HEADERS = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36",
        "Cookie": MEU_COOKIE
    }

def extrair_dados_livro(url_livro):
    """Acessa a página de um livro específico e extrai suas métricas."""
    
    dados = {
        "Título do Livro": None,
        "Autor": None,
        "Quantidade de Páginas": None,
        "Tempo de Leitura": None,
        "Nota Média": None,
        "Leram": None,
        "Lendo": None,
        "Querem": None,
        "Relendo": None,
        "Abandonos": None,
        "Resenhas": None,
        "Favoritos": None,
        "Avaliaram": None      
    }

    try: 
        resposta = requests.get(url_livro, headers=HEADERS, timeout=15) 
        
        if resposta.status_code == 200:
            soup = BeautifulSoup(resposta.text, 'html.parser')
            
            try:    # O .text extrai texto e o .strip() remove espaços em branco
                tag_titulo = soup.find('h1', class_='font-lato text-lg font-bold leading-6')
                if tag_titulo:
                    dados["Título do Livro"] = tag_titulo.text.strip()
            except: pass

            try:
                tag_autor = soup.find('h2', class_='my mt-2 font-lato text-base font-normal leading-5')
                if tag_autor:
                    dados["Autor"] = tag_autor.text.strip()    
            except: pass    

            try:
                tag_paginas = soup('span', class_='font-lato text-2xs text-contrast')[2]
                if tag_paginas:
                    dados["Quantidade de Páginas"] = tag_paginas.text.strip()
            except: pass 

            try:
                tag_tempoLeitura = soup('span', class_='font-lato text-2xs text-contrast')[3]
                if tag_tempoLeitura:
                    dados["Tempo de Leitura"] = tag_tempoLeitura.text.strip()  
            except: pass 

            try:
                tag_Nota = soup.find('span', class_='rounded-lg bg-success px-2 py-1 font-lato text-[24px] font-bold leading-8 text-white min-h-8 w-fit min-w-8')
                if tag_Nota:
                    dados["Nota Média"] = tag_Nota.text.strip()   
            except: pass 

            try:
                tag_Leram = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[0]
                if tag_Leram:
                    dados["Leram"] = tag_Leram.text.strip()  
            except: pass 

            try:
                tag_Lendo = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[1]
                if tag_Lendo:
                    dados["Lendo"] = tag_Lendo.text.strip()  
            except: pass 

            try:
                tag_Querem = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[2]
                if tag_Querem:
                    dados["Querem"] = tag_Querem.text.strip()
            except: pass 

            try:
                tag_Relendo = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[3]
                if tag_Relendo:
                    dados["Relendo"] = tag_Relendo.text.strip() 
            except: pass 

            try:
                tag_Abandonos = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[4]
                if tag_Abandonos:
                    dados["Abandonos"] = tag_Abandonos.text.strip()  
            except: pass 
            
            try:
                tag_Resenhas = soup('span', class_='font-lato text-[24px] font-bold leading-8 text-primary')[5]
                if tag_Resenhas:
                    dados["Resenhas"] = tag_Resenhas.text.strip()  
            except: pass 
            
            try:
                tag_Favoritos = soup('span', class_='ml-2')[0]
                if tag_Favoritos:
                    dados["Favoritos"] = tag_Favoritos.text.strip()
            except: pass 
            
            try:
                tag_Avaliaram = soup('span', class_='ml-2')[2]
                if tag_Avaliaram:
                    dados["Avaliaram"] = tag_Avaliaram.text.strip()
            except: pass 
                
        else:
            print(f"Erro {resposta.status_code} ao acessar {url_livro}")
                
    except Exception as e:
        print(f"Falha de conexão com {url_livro}: {e}")
        
    return dados

# Teste com o primeiro link do txt
with open(ARQUIVO_LINKS, 'r', encoding='utf-8') as f:
    primeiro_link = f.readline().strip()

print(f"Testando a extração no link: {primeiro_link}")
resultado_teste = extrair_dados_livro(primeiro_link)

for chave, valor in resultado_teste.items():
    print(f"{chave}: {valor}")
# Out:
# Testando a extração no link: https://www.skoob.com.br/pt/book/122552395
# Título do Livro: Alchemised [Edição brasileira] -
# Autor: SenLinYu
# Quantidade de Páginas: 900 páginas
# Tempo de Leitura: 1d 6h 0m
# Nota Média: 4.5
# Leram: 9839
# Lendo: 4976
# Querem: 49268
# Relendo: 46
# Abandonos: 628
# Resenhas: 2554
# Favoritos: 1778
# Avaliaram: 7318

# %%
import pandas as pd
import os
import time
import random

ARQUIVO_CSV = "skoob_todos_livros.csv"

with open(ARQUIVO_LINKS, 'r', encoding='utf-8') as f:
    todos_links = [linha.strip() for linha in f.readlines() if linha.strip()]

livros_raspados = 0
if os.path.exists(ARQUIVO_CSV):
    try:
        df_existente = pd.read_csv(ARQUIVO_CSV)
        livros_raspados = len(df_existente)
        print(f"Retomando progresso: {livros_raspados} livros já estão salvos no CSV.")
    except Exception as e:
        print("Aviso: O CSV existe, mas está vazio ou ilegível. Começando do zero.")

links_para_processar = todos_links[livros_raspados:5]
total_restante = len(links_para_processar)

print(f"Iniciando a extração de {total_restante} livros...\n")

for indice, link in enumerate(links_para_processar):
    print(f"[{indice + 1}/{total_restante}] Extraindo: {link}")
    
    dados_extraidos = extrair_dados_livro(link)
    
    df_linha = pd.DataFrame([dados_extraidos])
    
    precisa_cabecalho = not os.path.exists(ARQUIVO_CSV)
    
    df_linha.to_csv(
        ARQUIVO_CSV, 
        mode='a', 
        header=precisa_cabecalho, 
        index=False, 
        encoding="utf-8-sig"
    )
    
    time.sleep(random.uniform(1.0, 2.5))

print("\nExtração da base de dados finalizada com sucesso!")
# Out:
# Iniciando a extração de 5 livros...
#
# [1/5] Extraindo: https://www.skoob.com.br/pt/book/122552395
# [2/5] Extraindo: https://www.skoob.com.br/pt/book/122533691
# [3/5] Extraindo: https://www.skoob.com.br/pt/book/122565439
# [4/5] Extraindo: https://www.skoob.com.br/pt/book/122569958
# [5/5] Extraindo: https://www.skoob.com.br/pt/book/122565462
#
# Extração da base de dados finalizada com sucesso!

# %%
'''import pandas as pd
import requests
import time
import urllib.parse

API_KEY = ""

ARQUIVO_CSV = "skoob_todos_livros.csv"

def teste_preco_google(titulo):

    # Formata o título
    query = urllib.parse.quote(f'intitle:"{titulo}"')
    url = f"https://www.googleapis.com/books/v1/volumes?q={query}&key={API_KEY}&country=BR"
    
    try:
        resposta = requests.get(url, timeout=10)
        
        if resposta.status_code == 200:
            dados = resposta.json()
            
            if "items" in dados and len(dados["items"]) > 0:
                primeiro_livro = dados["items"][0]
                sale_info = primeiro_livro.get("saleInfo", {})
                
                if sale_info.get("saleability") == "FOR_SALE":
                    preco = sale_info.get("retailPrice", {}).get("amount")
                    return f"R$ {preco}"
                    
        else:
            return f"Erro na API: {resposta.status_code}"
            
    except Exception as e:
        return f"Erro de conexão: {e}"

print("INICIANDO TESTE GOOGLE BOOKS\n")

try:
    df_teste = pd.read_csv(ARQUIVO_CSV, sep=',').head(1)
    
    for indice, linha in df_teste.iterrows():
        titulo_livro = linha["Título do Livro"]
        print(f"Buscando: '{titulo_livro}'...")
        
        resultado = teste_preco_google(titulo_livro)
        print(f"-> {resultado}\n")
        
        # O Google é mais generoso com IPs, 0.5s é suficiente
        time.sleep(0.5)

except FileNotFoundError:
    print(f"Erro: O arquivo '{ARQUIVO_CSV}' não foi encontrado.")

print("--- TESTE FINALIZADO ---")'''
# Out:
# --- INICIANDO TESTE COM A GOOGLE BOOKS API ---
#
# Buscando: 'Alchemised [Edição brasileira] -'...
# -> R$ 62.91
#
# --- TESTE FINALIZADO ---

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import urllib.parse
import time
import random

API_KEY = ""
ARQUIVO_CSV = "skoob_todos_livros.csv"

df = pd.read_csv(ARQUIVO_CSV, sep=',')

if "Preço Digital (R$)" not in df.columns:
    df["Preço Digital (R$)"] = None
if "Preço Físico (R$)" not in df.columns:
    df["Preço Físico (R$)"] = None


def limpar_titulo(titulo):
    titulo_limpo = re.sub(r'[\(\[].*?[\)\]]', '', str(titulo))
    titulo_limpo = titulo_limpo.split(':')[0].split('-')[0]
    return titulo_limpo.strip()

def buscar_google_digital(titulo_limpo, autor):
        
    query = urllib.parse.quote(f'intitle:"{titulo_limpo}"' + f' inauthor:"{autor}"')
    url = f"https://www.googleapis.com/books/v1/volumes?q={query}&key={API_KEY}&country=BR"
    
    try:
        res = requests.get(url, timeout=10)
        if res.status_code == 200:
            dados = res.json()
            if "items" in dados:
                sale = dados["items"][0].get("saleInfo", {})
                if sale.get("saleability") == "FOR_SALE":
                    return sale.get("retailPrice", {}).get("amount")
    except:
        pass
    return "Não encontrado"

def buscar_ev_fisico(titulo_limpo, autor):
    termo_busca = titulo_limpo + f" {autor}"
        
    query = urllib.parse.quote(termo_busca)
    url = f"https://www.estantevirtual.com.br/busca?q={query}&condition=novo"
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36"}
    
    try:
        res = requests.get(url, headers=headers, timeout=10)
        if res.status_code == 200:
            soup = BeautifulSoup(res.text, 'html.parser')
            
            elementos_preco = soup.find_all('span', {'data-auto': 'price'})
            precos = []
            
            for tag in elementos_preco[:5]:
                texto_preco = tag.get_text()
                limpo = texto_preco.replace('R$', '').replace('\xa0', '').replace('.', '').replace(',', '.').strip()
                try:
                    valor_float = float(limpo)
                    if valor_float > 0:
                        precos.append(valor_float)
                except ValueError:
                    continue
            
            media = sum(precos) / len(precos)
            return round(media, 2)
                
    except Exception as e:
        print(f"Erro na EV para '{termo_busca}': {e}")
        
    return "Não encontrado"

# %%
linhas_pendentes = df[df["Preço Digital (R$)"].isnull() | df["Preço Físico (R$)"].isnull()].index
total_restante = len(linhas_pendentes)

print(f"Iniciando a busca\n")

for contador, indice in enumerate(linhas_pendentes):
    titulo_bruto = df.at[indice, "Título do Livro"]
    autor = df.at[indice, "Autor"] 
    
    titulo_limpo = limpar_titulo(titulo_bruto)
    
    if pd.isna(df.at[indice, "Preço Digital (R$)"]):
        preco_digital = buscar_google_digital(titulo_limpo, autor)
        df.at[indice, "Preço Digital (R$)"] = preco_digital
    else:
        preco_digital = df.at[indice, "Preço Digital (R$)"]
        
    if pd.isna(df.at[indice, "Preço Físico (R$)"]):
        time.sleep(random.uniform(0.5, 1.5))
        preco_fisico = buscar_ev_fisico(titulo_limpo, autor)
        df.at[indice, "Preço Físico (R$)"] = preco_fisico
    else:
        preco_fisico = df.at[indice, "Preço Físico (R$)"]
    
    print(f"[{contador+1}/{total_restante}] {str(titulo_limpo)} ({str(autor)}) | Digital: {preco_digital} | Físico: {preco_fisico}")
    
    if (contador + 1) % 20 == 0:
        df.to_csv(ARQUIVO_CSV, sep=',', index=False, encoding='utf-8-sig')

df.to_csv(ARQUIVO_CSV, sep=',', index=False, encoding='utf-8-sig')
print("\nProcesso finalizado com sucesso!")
# Out:
# Iniciando a busca altamente precisa para 5 livros...
#
# [1/5] Alchemised (SenLinYu)... -> Digital: 62.91 | Físico: 94.08
# [2/5] Sorte No Amor (Lynn Painter)... -> Digital: 40.41 | Físico: 47.96
# [3/5] Querida tia (Valérie Perrin)... -> Digital: 49.41 | Físico: 46.58
# [4/5] MURDLE (G. T. Karber)... -> Digital: Não encontrado | Físico: 32.38
# [5/5] Férias de matar (Tessa Bailey)... -> Digital: 42.21 | Físico: 24.9
#
# Processo finalizado com sucesso!
